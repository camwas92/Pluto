# %% [markdown]
# # Data Exploration #
# This file explores the different data sources

# %%
# load the data paths
from Core import SetUp as SU
import pandas as pd
paths = SU.collect_paths()
print(paths)
# Out:
# {'Input': WindowsPath('C:/Users/cwasilewsky/Google Drive/WORK/Post-Graduate/Capstone/Code/Input'), 'Output': WindowsPath('C:/Users/cwasilewsky/Google Drive/WORK/Post-Graduate/Capstone/Code/Output'), 'Source_Data': WindowsPath('C:/Users/cwasilewsky/Google Drive/WORK/Post-Graduate/Capstone/Data'), 'Base': WindowsPath('C:/Users/cwasilewsky/Google Drive/WORK/Post-Graduate/Capstone/Code')}

# %%
# load data sets
WestpacDf = pd.read_csv(paths['Source_Data'] / 'Westpac' / 'transactions.csv')
KaggleNoCatDf = pd.read_csv(paths['Source_Data'] / 'Kaggle' / '1BTransactionNoCategory.csv')
KaggleCatDf = pd.read_csv(paths['Source_Data'] / 'Kaggle' / 'TransactionsWithCategory.csv')

print('\n\nWestpac Data\n',WestpacDf.columns)
print('\n\nKaggleNoCat Data\n',KaggleNoCatDf.columns)
print('\n\nKaggleCat Data\n',KaggleCatDf.columns)
# Out:
# Westpac Data
#  Index(['Acct_key', 'Tran_group_code', 'Tran_type_code', 'Funds_type_code',
#        'Delivery_method', 'Location_desc', 'Date', 'Tran_amt'],
#       dtype='object')
#
#
# KaggleNoCat Data
#  Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')
#
#
# KaggleCat Data
#  Index(['step', 'customer', 'age', 'gender', 'zipcodeOri', 'merchant',
#        'zipMerchant', 'category', 'amount', 'fraud'],
#       dtype='object')

# %%
WestpacDf.describe(include='all')
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Acct_key</th>
#       <th>Tran_group_code</th>
#       <th>Tran_type_code</th>
#       <th>Funds_type_code</th>
#       <th>Delivery_method</th>
#       <th>Location_desc</th>
#       <th>Date</th>
#       <th>Tran_amt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>199645</td>
#       <td>199645</td>
#       <td>199645</td>
#       <td>199645</td>
#       <td>199645</td>
#       <td>199645</td>
#       <td>199645</td>
#       <td>199645.000000</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>1100</td>
#       <td>5</td>
#       <td>13</td>
#       <td>4</td>
#       <td>9</td>
#       <td>39429</td>
#       <td>771</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>top</th>
#       <td>SCRAC6PSTSJRQQ3</td>
#       <td>W</td>
#       <td>WPU</td>
#       <td>E</td>
#       <td>M</td>
# ...

# %%
KaggleNoCatDf.describe(include='all')
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>step</th>
#       <th>type</th>
#       <th>amount</th>
#       <th>nameOrig</th>
#       <th>oldbalanceOrg</th>
#       <th>newbalanceOrig</th>
#       <th>nameDest</th>
#       <th>oldbalanceDest</th>
#       <th>newbalanceDest</th>
#       <th>isFraud</th>
#       <th>isFlaggedFraud</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>6.362620e+06</td>
#       <td>6362620</td>
#       <td>6.362620e+06</td>
#       <td>6362620</td>
#       <td>6.362620e+06</td>
#       <td>6.362620e+06</td>
#       <td>6362620</td>
#       <td>6.362620e+06</td>
#       <td>6.362620e+06</td>
#       <td>6.362620e+06</td>
#       <td>6.362620e+06</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>NaN</td>
#       <td>5</td>
#       <td>NaN</td>
#       <td>6353307</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...

# %%
KaggleCatDf.describe(include='all')
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>step</th>
#       <th>customer</th>
#       <th>age</th>
#       <th>gender</th>
#       <th>zipcodeOri</th>
#       <th>merchant</th>
#       <th>zipMerchant</th>
#       <th>category</th>
#       <th>amount</th>
#       <th>fraud</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>594643.000000</td>
#       <td>594643</td>
#       <td>594643</td>
#       <td>594643</td>
#       <td>594643</td>
#       <td>594643</td>
#       <td>594643</td>
#       <td>594643</td>
#       <td>594643.000000</td>
#       <td>594643.000000</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>NaN</td>
#       <td>4112</td>
#       <td>8</td>
#       <td>4</td>
#       <td>1</td>
#       <td>50</td>
#       <td>1</td>
#       <td>15</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>top</th>
# ...
